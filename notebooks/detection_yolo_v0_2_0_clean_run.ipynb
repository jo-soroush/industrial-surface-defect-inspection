# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %%bash
# rm -rf /content/industrial-surface-defect-inspection
#
# mkdir -p /content/industrial-surface-defect-inspection
# unzip -q "/content/drive/MyDrive/DefectAI yolo_training /detection_yolo_v0_2_0_colab_package.zip" -d /content/industrial-surface-defect-inspection
#
# cd /content/industrial-surface-defect-inspection
# pwd
# ls
# Out:
# /content/industrial-surface-defect-inspection
# configs
# data
# docs
# pyproject.toml
# requirements.txt
# scripts
# src

# %%
# %%bash
# cd /content/industrial-surface-defect-inspection
#
# nvidia-smi
#
# python - <<'PY'
# import torch
# import numpy
#
# print("torch_version=", torch.__version__)
# print("torch_cuda_version=", torch.version.cuda)
# print("cuda_available=", torch.cuda.is_available())
# print("cuda_device_count=", torch.cuda.device_count())
#
# if torch.cuda.is_available():
#     print("cuda_device_name=", torch.cuda.get_device_name(0))
#
# print("numpy_version=", numpy.__version__)
# PY
# Out:
# Tue May 12 11:27:11 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 580.82.07              Driver Version: 580.82.07      CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA A100-SXM4-40GB          Off |   00000000:00:04.0 Off |                    0 |
# | N/A   31C    P0             45W /  400W |       0MiB /  40960MiB |      0%      Default |
# |                                         |                        |             Disabled |
# ...

# %%
# %%bash
# python -m pip install "ultralytics>=8.0,<9.0" "ultralytics-thop>=2.0.18" --no-deps
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 70.3 MB/s eta 0:00:00
# ...

# %%
# %%bash
# cd /content/industrial-surface-defect-inspection
#
# python - <<'PY'
# import torch
# import ultralytics
# import numpy
#
# print("torch_version=", torch.__version__)
# print("torch_cuda_version=", torch.version.cuda)
# print("cuda_available=", torch.cuda.is_available())
# print("cuda_device_count=", torch.cuda.device_count())
#
# if torch.cuda.is_available():
#     print("cuda_device_name=", torch.cuda.get_device_name(0))
#
# print("ultralytics_version=", ultralytics.__version__)
# print("numpy_version=", numpy.__version__)
# PY
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# torch_version= 2.10.0+cu128
# torch_cuda_version= 12.8
# cuda_available= True
# cuda_device_count= 1
# cuda_device_name= NVIDIA A100-SXM4-40GB
# ultralytics_version= 8.4.48
# numpy_version= 2.0.2

# %%
# %%bash
# cd /content/industrial-surface-defect-inspection
#
# PYTHONPATH=src python scripts/detection/train_yolo_detection.py \
#   --run-config configs/runs/yolo_train_v0_2_0.yaml \
#   --device 0 \
#   --validate-only
# Out:
# execution_mode=validate_only
# training_status=not_started
# run_training_enabled=false
# run_config_path=configs/runs/yolo_train_v0_2_0.yaml
# dataset_yaml_path=data/processed/gc10det_yolo/dataset.yaml
# dataset_id=gc10det_detection
# dataset_version=gc10det_1.0
# model_name=yolo
# backend=ultralytics
# backend_package=ultralytics
# ultralytics_available=true
# requirements_ultralytics_declared=true
# requirements_ultralytics_line=ultralytics>=8.0,<9.0
# split_counts=train:1610,validation:345,test:345
# class_count=10
# planned_epochs=50
# planned_batch_size=16
# planned_learning_rate=0.01
# planned_optimizer=auto
# planned_device=0
# planned_output_project=artifacts/detection/yolo/runs
# planned_output_name=yolo_train_v0_2_0
# planned_model_source=yolov8n.pt
# dataset_yaml_nc=10
# dataset_yaml_names=crease,crescent_gap,inclusion,oil_spot,punching_hole,rolled_pit,silk_spot,waist folding,water_spot,welding_line
# validated_split_counts=train:1610,validation:345,test:345
# ...

# %%
# %%bash
# cd /content/industrial-surface-defect-inspection
#
# if [ -e runs/detect/artifacts/detection/yolo/runs/yolo_train_v0_2_0 ]; then
#   echo "PARTIAL_OUTPUT_EXISTS"
#   find runs/detect/artifacts/detection/yolo/runs/yolo_train_v0_2_0 -maxdepth 3 -type f | sort
# else
#   echo "NO_PARTIAL_OUTPUT"
# fi
#
# if [ -e artifacts/detection/yolo/runs/yolo_train_v0_2_0 ]; then
#   echo "GOVERNED_OUTPUT_EXISTS"
#   find artifacts/detection/yolo/runs/yolo_train_v0_2_0 -maxdepth 3 -type f | sort
# else
#   echo "NO_GOVERNED_OUTPUT"
# fi
# Out:
# NO_PARTIAL_OUTPUT
# NO_GOVERNED_OUTPUT

# %%
# %%bash
# echo "=== content ==="
# ls -lah /content
#
# echo "=== drive training folder ==="
# find "/content/drive/MyDrive/DefectAI yolo_training " -maxdepth 4 -type f -o -type d 2>/dev/null | sort | head -100
# Out:
# === content ===
# total 24K
# drwxr-xr-x 1 root root 4.0K May 12 11:26 .
# drwxr-xr-x 1 root root 4.0K May 12 11:22 ..
# drwxr-xr-x 4 root root 4.0K May  6 13:32 .config
# drwx------ 5 root root 4.0K May 12 11:26 drive
# drwxr-xr-x 7 root root 4.0K May 12 11:27 industrial-surface-defect-inspection
# drwxr-xr-x 1 root root 4.0K May  6 13:32 sample_data
# === drive training folder ===
# /content/drive/MyDrive/DefectAI yolo_training
# /content/drive/MyDrive/DefectAI yolo_training /detection_yolo_v0_2_0_colab_package.zip

# %%
# %%bash
# cd /content/industrial-surface-defect-inspection
#
# PYTHONPATH=src python scripts/detection/train_yolo_detection.py \
#   --run-config configs/runs/yolo_train_v0_2_0.yaml \
#   --device 0 \
#   --run-training
# Out:
# ...
# Ultralytics 8.4.48 🚀 Python-3.12.13 torch-2.10.0+cu128 CUDA:0 (NVIDIA A100-SXM4-40GB, 40441MiB)
# ...

# %%
# %%bash
# cd /content/industrial-surface-defect-inspection
#
# echo "=== Actual YOLO output path ==="
# OUTPUT_DIR="runs/detect/artifacts/detection/yolo/runs/yolo_train_v0_2_0"
#
# if [ -d "$OUTPUT_DIR" ]; then
#   echo "OUTPUT_DIR_EXISTS"
#   find "$OUTPUT_DIR" -maxdepth 3 -type f | sort
# else
#   echo "OUTPUT_DIR_MISSING"
# fi
#
# echo "=== Required files ==="
# ls -lh "$OUTPUT_DIR/weights/best.pt" "$OUTPUT_DIR/weights/last.pt" "$OUTPUT_DIR/results.csv" "$OUTPUT_DIR/args.yaml"
# Out:
# === Actual YOLO output path ===
# OUTPUT_DIR_EXISTS
# runs/detect/artifacts/detection/yolo/runs/yolo_train_v0_2_0/args.yaml
# runs/detect/artifacts/detection/yolo/runs/yolo_train_v0_2_0/BoxF1_curve.png
# runs/detect/artifacts/detection/yolo/runs/yolo_train_v0_2_0/BoxP_curve.png
# runs/detect/artifacts/detection/yolo/runs/yolo_train_v0_2_0/BoxPR_curve.png
# runs/detect/artifacts/detection/yolo/runs/yolo_train_v0_2_0/BoxR_curve.png
# runs/detect/artifacts/detection/yolo/runs/yolo_train_v0_2_0/confusion_matrix_normalized.png
# runs/detect/artifacts/detection/yolo/runs/yolo_train_v0_2_0/confusion_matrix.png
# runs/detect/artifacts/detection/yolo/runs/yolo_train_v0_2_0/labels.jpg
# runs/detect/artifacts/detection/yolo/runs/yolo_train_v0_2_0/results.csv
# runs/detect/artifacts/detection/yolo/runs/yolo_train_v0_2_0/results.png
# runs/detect/artifacts/detection/yolo/runs/yolo_train_v0_2_0/train_batch0.jpg
# runs/detect/artifacts/detection/yolo/runs/yolo_train_v0_2_0/train_batch1.jpg
# ...

# %%
# %%bash
# cd /content/industrial-surface-defect-inspection
#
# SOURCE_DIR="runs/detect/artifacts/detection/yolo/runs/yolo_train_v0_2_0"
# TARGET_DIR="artifacts/detection/yolo/runs/yolo_train_v0_2_0"
#
# mkdir -p "artifacts/detection/yolo/runs"
# rm -rf "$TARGET_DIR"
# cp -a "$SOURCE_DIR" "$TARGET_DIR"
#
# echo "=== Governed output check ==="
# ls -lh "$TARGET_DIR/weights/best.pt" "$TARGET_DIR/weights/last.pt" "$TARGET_DIR/results.csv" "$TARGET_DIR/args.yaml"
# Out:
# === Governed output check ===
# -rw-r--r-- 1 root root 1.7K May 12 11:28 artifacts/detection/yolo/runs/yolo_train_v0_2_0/args.yaml
# -rw-r--r-- 1 root root 6.4K May 12 11:37 artifacts/detection/yolo/runs/yolo_train_v0_2_0/results.csv
# -rw-r--r-- 1 root root 6.0M May 12 11:37 artifacts/detection/yolo/runs/yolo_train_v0_2_0/weights/best.pt
# -rw-r--r-- 1 root root 6.0M May 12 11:37 artifacts/detection/yolo/runs/yolo_train_v0_2_0/weights/last.pt

# %%
# %%bash
# cd /content/industrial-surface-defect-inspection
#
# echo "=== Final results.csv row ==="
# python - <<'PY'
# import csv
# from pathlib import Path
#
# path = Path("artifacts/detection/yolo/runs/yolo_train_v0_2_0/results.csv")
#
# with path.open() as f:
#     rows = list(csv.DictReader(f))
#
# last = rows[-1]
# print("rows=", len(rows))
# for key, value in last.items():
#     print(f"{key.strip()}={value}")
# PY
# Out:
# === Final results.csv row ===
# rows= 50
# epoch=50
# time=532.444
# train/box_loss=1.29891
# train/cls_loss=0.8877
# train/dfl_loss=1.18993
# metrics/precision(B)=0.36791
# metrics/recall(B)=0.51132
# metrics/mAP50(B)=0.415
# metrics/mAP50-95(B)=0.2017
# val/box_loss=2.02502
# val/cls_loss=1.61027
# val/dfl_loss=1.55443
# lr/pg0=2.12772e-05
# lr/pg1=2.12772e-05
# lr/pg2=2.12772e-05

# %%
# %%bash
# cd /content/industrial-surface-defect-inspection
#
# mkdir -p "/content/drive/MyDrive/DefectAI yolo_training /outputs"
#
# zip -r "/content/drive/MyDrive/DefectAI yolo_training /outputs/yolo_train_v0_2_0_outputs.zip" \
#   artifacts/detection/yolo/runs/yolo_train_v0_2_0
#
# ls -lh "/content/drive/MyDrive/DefectAI yolo_training /outputs/yolo_train_v0_2_0_outputs.zip"
# Out:
#   adding: artifacts/detection/yolo/runs/yolo_train_v0_2_0/ (stored 0%)
#   adding: artifacts/detection/yolo/runs/yolo_train_v0_2_0/weights/ (stored 0%)
#   adding: artifacts/detection/yolo/runs/yolo_train_v0_2_0/weights/last.pt (deflated 9%)
#   adding: artifacts/detection/yolo/runs/yolo_train_v0_2_0/weights/best.pt (deflated 9%)
#   adding: artifacts/detection/yolo/runs/yolo_train_v0_2_0/val_batch1_labels.jpg (deflated 19%)
#   adding: artifacts/detection/yolo/runs/yolo_train_v0_2_0/labels.jpg (deflated 22%)
#   adding: artifacts/detection/yolo/runs/yolo_train_v0_2_0/train_batch4040.jpg (deflated 27%)
#   adding: artifacts/detection/yolo/runs/yolo_train_v0_2_0/val_batch2_labels.jpg (deflated 14%)
#   adding: artifacts/detection/yolo/runs/yolo_train_v0_2_0/BoxP_curve.png (deflated 5%)
#   adding: artifacts/detection/yolo/runs/yolo_train_v0_2_0/val_batch0_labels.jpg (deflated 20%)
#   adding: artifacts/detection/yolo/runs/yolo_train_v0_2_0/results.csv (deflated 61%)
# ...

# %%
# %%bash
# unzip -l "/content/drive/MyDrive/DefectAI yolo_training /outputs/yolo_train_v0_2_0_outputs.zip" | grep -E "best.pt|last.pt|results.csv|args.yaml|confusion_matrix.png|results.png"
# Out:
#   6226666  2026-05-12 11:37   artifacts/detection/yolo/runs/yolo_train_v0_2_0/weights/last.pt
#   6226666  2026-05-12 11:37   artifacts/detection/yolo/runs/yolo_train_v0_2_0/weights/best.pt
#      6455  2026-05-12 11:37   artifacts/detection/yolo/runs/yolo_train_v0_2_0/results.csv
#    318297  2026-05-12 11:37   artifacts/detection/yolo/runs/yolo_train_v0_2_0/results.png
#    229106  2026-05-12 11:37   artifacts/detection/yolo/runs/yolo_train_v0_2_0/confusion_matrix.png
#      1714  2026-05-12 11:28   artifacts/detection/yolo/runs/yolo_train_v0_2_0/args.yaml

# %%
# %%bash
# cd /content/industrial-surface-defect-inspection
#
# mkdir -p "/content/drive/MyDrive/DefectAI yolo_training /outputs"
#
# {
#   echo "=== Training Run Evidence ==="
#   echo "run_id=yolo_train_v0_2_0"
#   echo "trained_at_colab_time=$(date -u)"
#   echo ""
#   echo "=== GPU ==="
#   nvidia-smi
#   echo ""
#   echo "=== Python / Torch / Ultralytics / NumPy ==="
#   python - <<'PY'
# import torch
# import ultralytics
# import numpy
# import sys
#
# print("python_version=", sys.version)
# print("torch_version=", torch.__version__)
# print("torch_cuda_version=", torch.version.cuda)
# print("cuda_available=", torch.cuda.is_available())
# print("cuda_device_count=", torch.cuda.device_count())
# if torch.cuda.is_available():
#     print("cuda_device_name=", torch.cuda.get_device_name(0))
# print("ultralytics_version=", ultralytics.__version__)
# print("numpy_version=", numpy.__version__)
# PY
#   echo ""
#   echo "=== Final results.csv row ==="
#   python - <<'PY'
# import csv
# from pathlib import Path
#
# path = Path("artifacts/detection/yolo/runs/yolo_train_v0_2_0/results.csv")
# rows = list(csv.DictReader(path.open()))
# last = rows[-1]
# print("rows=", len(rows))
# for key, value in last.items():
#     print(f"{key.strip()}={value}")
# PY
# } > "/content/drive/MyDrive/DefectAI yolo_training /outputs/yolo_train_v0_2_0_environment_evidence.txt"
#
# ls -lh "/content/drive/MyDrive/DefectAI yolo_training /outputs/yolo_train_v0_2_0_environment_evidence.txt"
# Out:
# -rw------- 1 root root 2.5K May 12 11:49 /content/drive/MyDrive/DefectAI yolo_training /outputs/yolo_train_v0_2_0_environment_evidence.txt

# %%
# %%bash
# cat "/content/drive/MyDrive/DefectAI yolo_training /outputs/yolo_train_v0_2_0_environment_evidence.txt"
# Out:
# === Training Run Evidence ===
# run_id=yolo_train_v0_2_0
# trained_at_colab_time=Tue May 12 11:49:13 AM UTC 2026
#
# === GPU ===
# Tue May 12 11:49:13 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 580.82.07              Driver Version: 580.82.07      CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA A100-SXM4-40GB          Off |   00000000:00:04.0 Off |                    0 |
# ...
